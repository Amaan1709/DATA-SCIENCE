# %% [markdown]
# # Capstone Project: Titanic Survival Analysis
#
# This project will test your skills in data loading, cleaning, manipulation, and visualization using NumPy, Pandas, Matplotlib, and Seaborn. You will be working with the famous Titanic dataset.
#
# *Dataset Source:* The dataset typically comes as train.csv and test.csv on Kaggle. For this project, we will focus on the train.csv file, which contains passenger information and whether they survived. You can download it from Kaggle: [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data)
#
# *Instructions:*
# 1. Download the train.csv file and place it in the same directory as this Jupyter Notebook.
# 2. Complete each question in the designated "Your Answer" cell.
# 3. Use comments to explain your code where necessary.
# 4. Ensure your visualizations are well-labeled and easy to interpret.
# 5. Feel free to add additional exploratory analysis or visualizations if you wish!

# %% [markdown]
# ## Question 1: Load the Dataset and Initial Inspection
# Import the necessary libraries: pandas, numpy, matplotlib.pyplot, and seaborn.<br>
# Load the 'train.csv' dataset into a Pandas DataFrame.<br>
# Display the first 5 rows of the DataFrame.<br>
# Display basic information about the DataFrame (e.g., column types, non-null counts).<br>
# Check for missing values in each column and display the count.<br>

# %%
# Your Answer: Question 1

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head() #first 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info() #basic information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum() #null values count
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ---
# ## Question 2: Data Cleaning and Preprocessing
# Based on the missing values, decide how to handle them for 'Age', 'Cabin', and 'Embarked'.<br>
# For 'Age', fill missing values with the median age.<br>
# For 'Embarked', fill missing values with the most frequent embarkation point.<br>
# For 'Cabin', since there are too many missing values, drop this column.<br>
# Verify that there are no more missing values in the processed columns.<br>

# %%
# Your Answer: Question 2
df1 = df
df1['Age'] = df1['Age'].fillna(df['Age'].median())
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1['Embarked'] = df1['Embarked'].fillna(df['Embarked'].mode()[0])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1 = df1.dropna(axis=1)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.info() # no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %% [markdown]
# ---
# ## Question 3: Exploratory Data Analysis - Numerical Features
# Calculate and display the descriptive statistics (mean, median, std, etc.) for 'Age' and 'Fare'.<br>
# Create a histogram for 'Age' to visualize its distribution.<br>
# Create a histogram for 'Fare' to visualize its distribution (consider applying a log transformation if it's heavily skewed).<br>
# Use Seaborn to create a box plot of 'Age' grouped by 'Survived' to see age distribution differences between survivors and non-survivors.

# %%
# Your Answer: Question 3

#Age
mean_age=df1['Age'].mean()
print('MEAN Of AGE =',mean_age)
median_age=df1['Age'].median()
print('MEDIAN Of AGE =',median_age)
std_age=df1['Age'].std()
print('STD DEV Of AGE =',std_age)

print('-'*50)

#Fare
mean_fare=df1['Fare'].mean()
print('MEAN Of FARE =',mean_fare)
median_fare=df1['Fare'].median()
print('MEDIAN Of FARE =',median_fare)
std_fare=df1['Fare'].std()
print('STD DEV Of FARE =',std_fare)
# Out:
# MEAN Of AGE = 29.36158249158249
# MEDIAN Of AGE = 28.0
# STD DEV Of AGE = 13.019696550973194
# --------------------------------------------------
# MEAN Of FARE = 32.204207968574636
# MEDIAN Of FARE = 14.4542
# STD DEV Of FARE = 49.693428597180905

# %%
sns.histplot(df1['Age'],bins=10,color='red')
plt.title("AGE DISTRIBUTION")
# Out:
# Text(0.5, 1.0, 'AGE DISTRIBUTION')

# %%
sns.histplot(df1['Fare'],bins=10,log_scale=True,color='cyan')
plt.title("FARE DISTRIBUTION")
# Out:
# Text(0.5, 1.0, 'FARE DISTRIBUTION')

# %%
# In survived
# 0 means not survived 
# 1 means survived


sns.boxplot(x='Survived',y='Age',data=df1, hue='Survived', legend=False)
plt.title('AGE VS SURVIVORS')
# Out:
# Text(0.5, 1.0, 'AGE VS SURVIVORS')

# %%
# In survived
# 0 means not survived 
# 1 means survived


sns.boxplot(x='Sex',y='Age',data=df1, hue='Survived', legend=False)
plt.title('AGE VS SURVIVORS ACCORDING to SEX')
# Out:
# Text(0.5, 1.0, 'AGE VS SURVIVORS ACCORDING to SEX')

# %% [markdown]
# ---
# ## Question 4: Exploratory Data Analysis - Categorical Features
# Count and display the number of survivors and non-survivors.<br>
# Create a countplot using Seaborn to visualize the distribution of 'Survived'.<br>
# Create a countplot using Seaborn to visualize the survival count by 'Sex'.<br>
# Create a countplot using Seaborn to visualize the survival count by 'Pclass' (Passenger Class).<br>
# Create a countplot using Seaborn to visualize the survival count by 'Embarked'.

# %%
# Your Answer: Question 4

df1['Survived'].value_counts()

# In survived
# 0 means non-survivors 
# 1 means survivors
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# In survived
# 0 means not survived 
# 1 means survived
sns.countplot(x='Survived',data=df1,hue='Survived')
plt.title('SURVIVED DISTRIBUTION')
# Out:
# Text(0.5, 1.0, 'SURVIVED DISTRIBUTION')

# %%
# In survived
# 0 means not survived 
# 1 means survived
sns.countplot(x='Sex',data=df1,hue='Survived')
plt.title('SURVIVAL COUNT BY SEX DISTRIBUTION')
# Out:
# Text(0.5, 1.0, 'SURVIVAL COUNT BY SEX DISTRIBUTION')

# %%
# In survived
# 0 means not survived 
# 1 means survived
sns.countplot(x='Pclass',data=df1,hue='Survived')
plt.xlabel('PASSENGER CLASS')
plt.title('SURVIVAL COUNT BY PASSENGER CLASS DISTRIBUTION')
# Out:
# Text(0.5, 1.0, 'SURVIVAL COUNT BY PASSENGER CLASS DISTRIBUTION')

# %%
# In survived
# 0 means not survived 
# 1 means survived

# In Embarked
# C means Cherbourg
# Q means Queentown
# S means Southampton

sns.countplot(x='Embarked',data=df1,hue='Survived')
plt.title('SURVIVAL COUNT BY EMBARKED DISTRIBUTION')
# Out:
# Text(0.5, 1.0, 'SURVIVAL COUNT BY EMBARKED DISTRIBUTION')

# %% [markdown]
# ---
# ## Question 5: Feature Engineering and Relationships
# Create a new feature 'FamilySize' by summing 'SibSp' (siblings/spouses) and 'Parch' (parents/children) and adding 1 (for the passenger themselves).<br>
# Create a new categorical feature 'Alone' based on 'FamilySize': 1 if FamilySize is 1 (alone), 0 otherwise.<br>
# Use Seaborn to create a heatmap of the correlation matrix for numerical features (including 'FamilySize').<br>
# Analyze the correlation between 'FamilySize', 'Fare', 'Age', and 'Survived'.

# %%
# Your Answer: Question 5

df1['FamilySize'] = df1['SibSp'] + df1['Parch'] + 1
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['Alone'] = (df1['FamilySize']==1).astype(int)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
num_features = df1[['Survived','Fare','Age','FamilySize']]
sns.heatmap(num_features.corr(),annot=True,cmap='rocket',fmt='.2f')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ---
# ## Question 6: Advanced Visualization
# Create a FacetGrid using Seaborn to visualize the distribution of 'Age' for different 'Pclass' and 'Sex' combinations, with 'Survived' as a hue.<br>
# This will involve creating multiple histograms or KDE plots for each combination.

# %%
# Your Answer: Question 6

g = sns.FacetGrid(df1, row="Sex", col="Pclass", hue="Survived", margin_titles=True,)
g.map(sns.histplot, "Age", kde=True, bins=20,legend=True)
plt.xlabel("Age")
plt.legend()
plt.ylabel('count')
plt.show()

# %% [markdown]
# ---
# ## Question 7: Final Insights
# Based on your analysis, summarize the key factors that influenced survival on the Titanic.<br>
# Provide at least 3 insights backed by your visualizations and numerical analysis.

# %% [markdown]
# # Your Answer: Question 6
#
# 1. Gender Played a Big Role
# -->Women had a much higher chance of survival than men.
# -->This matches the idea of "women and children first" during rescue.
# -->Most women survived, but only a small number of men did.
#
# 2. Passenger Class Mattered
# -->People who were in 1st class had the highest survival rate.
# -->Those in 3rd class (the lower class) had the lowest chance.
# -->It clearly shows that wealth and position on the ship made a difference.
#
# 3. Age Had an Impact
# -->Younger people, especially children, had better chances of surviving.
# -->Many small kids were saved.
# -->Older people had lower chances compared to kids.
